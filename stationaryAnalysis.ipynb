# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("stationary.csv")

imuSet = df.loc[df["MessageType"] == 'Imu']
wheelSpeedsSet = df.loc[df["MessageType"] == 'WheelSpeeds']
conesSet = df.loc[df["MessageType"] == 'Cones']
gpsSet = df.loc[df["MessageType"] == 'GPS']
carState = df.loc[df["MessageType"] == 'CarState']

# %%
wheelSpeedsSet["LeftFrontSpeed"].describe()
# Out:
# count     814.000000
# mean      999.016347
# std         0.970311
# min       995.428772
# 25%       998.344391
# 50%       998.991333
# 75%       999.735550
# max      1001.896484
# Name: LeftFrontSpeed, dtype: float64

# %%
wheelSpeedsSet["RightBackSpeed"].plot()
wheelSpeedsSet["LeftBackSpeed"].plot()
# Out:
# <AxesSubplot:>

# %%
import math
wheelSpeedsSet["RightBackSpeed"].std()
# Out:
# 0.9805752530801943
